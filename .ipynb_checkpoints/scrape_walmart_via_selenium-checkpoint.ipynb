# %%
from lxml import html  
import csv,os,json
import requests
from time import sleep
import ast
import re
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path=r'C:\Geckodriver\chromedriver.exe')
driver.set_page_load_timeout(500)

# %%
def WalmartParser(url):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.90 Safari/537.36'}
    driver.get(url)
    #print(driver)
    page = driver.page_source
    rpage = requests.get(url,headers=headers)
   
    while True:
        sleep(3)
        try:
            doc = html.fromstring(page)
            script_data = doc.xpath('//script[contains(., "Specifications")]/text()')[0]
            
            XPATH_NAME = '//h1[contains(@class,"prod-ProductTitle")]/div/text()'
            XPATH_SALE_PRICE = '//span[@class="display-inline-block-xs prod-PaddingRight--s"]//text()'
            XPATH_CATEGORY = '//ol[@class="breadcrumb-list "]//text()'
            XPATH_RATING = '//span[@class="seo-avg-rating" and @itemprop="ratingValue"]/text()'
             
            
            ''' 
            XPATH_SALE_PRICE = '//span[contains(@class,"offer-price") and contains(@class,"a-size-medium")]//text()'
            #XPATH_ORIGINAL_PRICE = '//td[contains(text(),"List Price") or contains(text(),"M.R.P") or contains(text(),"Price")]/following-sibling::td/text()'
            XPATH_CATEGORY = '//a[@class="a-link-normal a-color-tertiary"]//text()'
            XPATH_AVAILABILITY = '//div[@id="availability"]//text()' 
            XPATH_AUTHOR = '//a[contains(@class,"contributorNameID")]//text()'
            XPATH_ISBN10 = '//li/b[contains(text(),"ISBN-10:")]/following-sibling::text()'
            XPATH_PAGES = '//li/b[contains(text(),"Paperback")]/following-sibling::text()'
            XPATH_PUBLISHER = '//li/b[contains(text(),"Publisher")]/following-sibling::text()'
            XPATH_LANGUAGE = '//li/b[contains(text(),"Language")]/following-sibling::text()'
            XPATH_DIMENSIONS = '//li/b[contains(text(),"Dimensions")]/following-sibling::text()'
            XPATH_WEIGHT = '//li/b[contains(text(),"Weight")]/following-sibling::text()'
            XPATH_RATING = '//li/b[contains(text(),"Average Customer Review:")]/following-sibling::span/span/a/i/span/text()'
            '''
           
            RAW_NAME = doc.xpath(XPATH_NAME)
            RAW_SALE_PRICE = doc.xpath(XPATH_SALE_PRICE)
            RAW_CATEGORY = doc.xpath(XPATH_CATEGORY)
            RAW_RATING = doc.xpath(XPATH_RATING)
            print(RAW_SALE_PRICE)
           # RAW_AUTHOR = doc.xpath(XPATH_AUTHOR)
            '''
            
            
            ##RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
            RAw_AVAILABILITY = doc.xpath(XPATH_AVAILABILITY)
            
            RAW_ISBN10 = doc.xpath(XPATH_ISBN10)
            RAW_PAGES = doc.xpath(XPATH_PAGES)
            RAW_PUBLISHER = doc.xpath(XPATH_PUBLISHER) 
            RAW_LANGUAGE = doc.xpath(XPATH_LANGUAGE)
            RAW_DIMENSIONS = doc.xpath(XPATH_DIMENSIONS)
            RAW_WEIGHT = doc.xpath(XPATH_WEIGHT)
            RAW_RATING = doc.xpath(XPATH_RATING)
            '''
            
            AUTHOR, PUBLISHER, LANGUAGE, PAGES, ISBN10, DIMENSIONS = None, None, None, None, None, None
            

            data = re.search(r'"Specifications":(.*?),"ShortDescription', script_data).group(1)
            #print(data)
            #import json
            #data = json.loads(data)
            data = ast.literal_eval(data)
            data = (data["specifications"]["values"][0])
            for item in data:
                #print item
                for k,v in item.items():
                    if k == "author":
                        RAW_AUTHOR = v['values']
                        AUTHOR = ''.join(RAW_AUTHOR).strip() if RAW_AUTHOR else None
                        
                    elif k == "publisher":
                        RAW_PUBLISHER = v['values']
                        PUBLISHER = ''.join(RAW_PUBLISHER).strip() if RAW_PUBLISHER else None

                    elif k == "languages":
                        RAW_LANGUAGE = v['values']
                        LANGUAGE = ''.join(RAW_LANGUAGE).strip() if RAW_LANGUAGE else None
                        
                    elif k == "number_of_pages":
                        RAW_PAGES = v['values']
                        PAGES = ''.join(RAW_PAGES).strip() if RAW_PAGES else None

                    elif k == "isbn-10":
                        RAW_ISBN10 = v['values']
                        ISBN10 = ''.join(RAW_ISBN10).strip() if RAW_ISBN10 else None
                    elif k == "dimension":
                        RAW_DIMENSIONS = v['values']
                        DIMENSIONS = ''.join(RAW_DIMENSIONS).strip() if RAW_DIMENSIONS else None
                    
            #AUTHOR = data
            
            #print AUTHOR
 
            NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
            SALE_PRICE = ' '.join(''.join(RAW_SALE_PRICE).split()).strip() if RAW_SALE_PRICE else None
            CATEGORY = ' > '.join([i.strip() for i in RAW_CATEGORY]) if RAW_CATEGORY else None
            RATING = ''.join(RAW_RATING).strip() if RAW_RATING else None
            
           
            
            #print AUTHOR, PAGES, PUBLISHER
            '''
            WEIGHT = ''.join(RAW_WEIGHT).strip().strip('()').strip() if RAW_WEIGHT else None
            RATING = ''.join(RAW_RATING).strip() if RAW_RATING else None
            #if not ORIGINAL_PRICE:
                #ORIGINAL_PRICE = SALE_PRICE
                '''
 
            if rpage.status_code!=200 or not NAME or NAME == "":
                raise ValueError('captha')
            data = {
                    'NAME':NAME,
                    'SALE_PRICE':SALE_PRICE,
                    'CATEGORY':CATEGORY,
                   # 'AVAILABILITY':AVAILABILITY,
                    'URL':url,
                    'AUTHOR' : AUTHOR,
                    'ISBN10' : ISBN10,
                    'PAGES' : PAGES,
                    'PUBLISHER' : PUBLISHER,
                    'LANGUAGE' : LANGUAGE,
                    'DIMENSIONS' : DIMENSIONS,
                    #'WEIGHT' : WEIGHT,
                    'RATING' : RATING,
                    }
 
            return data
        except Exception as e:
            print("Retrying with exception ")
            driver.get(url)
            #print(driver)
            rpage = requests.get(url,headers=headers)
            page = driver.page_source

# %%
extracted_data = []
def ReadAsin(AsinList):
    count = 0
    # AsinList = csv.DictReader(open(os.path.join(os.path.dirname(__file__),"Asinfeed.csv")))
    for i in AsinList:
        url = "http://www.walmart.com/ip/"+i
        print("Processing: "+url)
        extracted_data.append(WalmartParser(url))
        count += 1
        #sleep(5)
        print(count)
    f=open('data_walmart.json','w')
    json.dump(extracted_data,f,indent=4)

# %%
formatted_asin = []
df = pd.read_csv("walmart_product_asins.csv")
for index, row in df.iterrows():
    #print(row[1])
    formatted_asin.append(str(row[1]))

# %%
if __name__ == "__main__":
    ReadAsin(formatted_asin[1500:1800])
# Out:
# Processing: https://www.walmart.com/ip/19895242
# ['$', '8', '.', '99']
# 1
# Processing: https://www.walmart.com/ip/6019745
# ['$', '16', '.', '07']
# 2
# Processing: https://www.walmart.com/ip/38183664
# ['$', '9', '.', '12']
# 3
# Processing: https://www.walmart.com/ip/52869455
# ['$', '5', '.', '83']
# 4
# Processing: https://www.walmart.com/ip/55817103
# ['$', '19', '.', '04']
# 5
# Processing: https://www.walmart.com/ip/47048959
# ['$', '7', '.', '19']
# 6
# Processing: https://www.walmart.com/ip/54980114
# ['$', '7', '.', '19']
# 7
# Processing: https://www.walmart.com/ip/50986961
# ['$', '4', '.', '99']
# 8
# Processing: https://www.walmart.com/ip/206557607
# Retrying with exception
# ['$', '20', '.', '29']
# 9
# Processing: https://www.walmart.com/ip/38184924
# ['$', '25', '.', '00']
# 10
# Processing: https://www.walmart.com/ip/54980364
# ['$', '11', '.', '97']
# 11
# Processing: https://www.walmart.com/ip/24180826
# ['$', '8', '.', '48']
# 12
# Processing: https://www.walmart.com/ip/55970405
# ['$', '12', '.', '26']
# 13
# Processing: https://www.walmart.com/ip/266876176
# ['$', '13', '.', '26']
# 14
# Processing: https://www.walmart.com/ip/24845875
# ['$', '9', '.', '17']
# 15
# Processing: https://www.walmart.com/ip/56106361
# ['$', '14', '.', '11']
# 16
# Processing: https://www.walmart.com/ip/53595661
# ['$', '8', '.', '65']
# 17
# Processing: https://www.walmart.com/ip/53921666
# ['$', '22', '.', '88']
# 18
# Processing: https://www.walmart.com/ip/2226624
# ['$', '3', '.', '99']
# 19
# Processing: https://www.walmart.com/ip/50986842
# ['$', '7', '.', '19']
# 20
# Processing: https://www.walmart.com/ip/47142276
# ['$', '9', '.', '94']
# 21
# Processing: https://www.walmart.com/ip/23734801
# ['$', '22', '.', '29']
# 22
# Processing: https://www.walmart.com/ip/26807463
# ['$', '7', '.', '97']
# 23
# Processing: https://www.walmart.com/ip/54868876
# ['$', '25', '.', '24']
# 24
# Processing: https://www.walmart.com/ip/55699408
# ['$', '22', '.', '56']
# 25
# Processing: https://www.walmart.com/ip/2195118
# ['$', '7', '.', '48']
# 26
# Processing: https://www.walmart.com/ip/55680624
# ['$', '15', '.', '59']
# 27
# Processing: https://www.walmart.com/ip/8132170
# ['$', '4', '.', '84']
# 28
# Processing: https://www.walmart.com/ip/249086030
# ['$', '7', '.', '99']
# 29
# Processing: https://www.walmart.com/ip/25653811
# ['$', '7', '.', '99']
# 30
# Processing: https://www.walmart.com/ip/37782357
# ['$', '13', '.', '23']
# 31
# Processing: https://www.walmart.com/ip/54214226
# ['$', '10', '.', '84']
# 32
# Processing: https://www.walmart.com/ip/22607341
# ['$', '6', '.', '90']
# 33
# Processing: https://www.walmart.com/ip/39786472
# ['$', '12', '.', '94']
# 34
# Processing: https://www.walmart.com/ip/55747281
# ['$', '6', '.', '79']
# 35
# Processing: https://www.walmart.com/ip/55971785
# ['$', '10', '.', '84']
# 36
# Processing: https://www.walmart.com/ip/21276921
# ['$', '8', '.', '92']
# 37
# Processing: https://www.walmart.com/ip/5621199
# ['$', '7', '.', '19']
# 38
# Processing: https://www.walmart.com/ip/4231140
# ['$', '7', '.', '08']
# 39
# Processing: https://www.walmart.com/ip/52564654
# ['$', '4', '.', '07']
# 40
# Processing: https://www.walmart.com/ip/25673559
# ['$', '7', '.', '99']
# 41
# Processing: https://www.walmart.com/ip/50554858
# ['$', '6', '.', '48']
# 42
# Processing: https://www.walmart.com/ip/3986737
# ['$', '7', '.', '34']
# 43
# Processing: https://www.walmart.com/ip/55812186
# ['$', '23', '.', '24']
# 44
# Processing: https://www.walmart.com/ip/49622137
# ['$', '8', '.', '98']
# 45
# Processing: https://www.walmart.com/ip/49526195
# ['$', '20', '.', '29']
# 46
# Processing: https://www.walmart.com/ip/45844153
# ['$', '12', '.', '29']
# 47
# Processing: https://www.walmart.com/ip/20663674
# ['$', '5', '.', '03']
# 48
# Processing: https://www.walmart.com/ip/51793596
# ['$', '13', '.', '38']
# 49
# Processing: https://www.walmart.com/ip/193164454
# ['$', '28', '.', '99']
# 50
# Processing: https://www.walmart.com/ip/15228410
# ['$', '7', '.', '98']
# 51
# Processing: https://www.walmart.com/ip/13444474
# ['$', '8', '.', '09']
# 52
# Processing: https://www.walmart.com/ip/56176319
# ['$', '22', '.', '90']
# 53
# Processing: https://www.walmart.com/ip/339215676
# ['$', '18', '.', '63']
# 54
# Processing: https://www.walmart.com/ip/32634637
# ['$', '7', '.', '64']
# 55
# Processing: https://www.walmart.com/ip/25672216
# ['$', '3', '.', '49']
# Retrying with exception
# ['$', '3', '.', '49']
# 56
# Processing: https://www.walmart.com/ip/40794852
# ['$', '7', '.', '99']
# 57
# Processing: https://www.walmart.com/ip/1541336
# ['$', '6', '.', '77']
# 58
# Processing: https://www.walmart.com/ip/56176587
# ['$', '16', '.', '20']
# 59
# Processing: https://www.walmart.com/ip/16716228
# ['$', '12', '.', '80']
# 60
# Processing: https://www.walmart.com/ip/51332355
# ['$', '6', '.', '40']
# 61
# Processing: https://www.walmart.com/ip/53719056
# ['$', '3', '.', '99']
# 62
# Processing: https://www.walmart.com/ip/55518029
# ['$', '6', '.', '49']
# 63
# Processing: https://www.walmart.com/ip/13026329
# ['$', '7', '.', '99']
# 64
# Processing: https://www.walmart.com/ip/56076044
# ['$', '4', '.', '12']
# 65
# Processing: https://www.walmart.com/ip/13397437
# ['$', '21', '.', '16']
# 66
# Processing: https://www.walmart.com/ip/21521246
# ['$', '11', '.', '99']
# 67
# Processing: https://www.walmart.com/ip/56077011
# ['$', '17', '.', '13']
# 68
# Processing: https://www.walmart.com/ip/9850669
# ['$', '8', '.', '00']
# 69
# Processing: https://www.walmart.com/ip/52573669
# ['$', '7', '.', '49']
# 70
# Processing: https://www.walmart.com/ip/20709019
# ['$', '12', '.', '95']
# 71
# Processing: https://www.walmart.com/ip/48587049
# ['$', '13', '.', '09']
# 72
# Processing: https://www.walmart.com/ip/17799850
# ['$', '8', '.', '74']
# 73
# Processing: https://www.walmart.com/ip/8462489
# ['$', '5', '.', '99']
# 74
# Processing: https://www.walmart.com/ip/421239949
# ['$', '11', '.', '01']
# 75
# Processing: https://www.walmart.com/ip/51330799
# ['$', '7', '.', '70']
# 76
# Processing: https://www.walmart.com/ip/56087784
# ['$', '19', '.', '37']
# 77
# Processing: https://www.walmart.com/ip/55623540
# ['$', '6', '.', '80']
# 78
# Processing: https://www.walmart.com/ip/20930960
# ['$', '7', '.', '48']
# 79
# Processing: https://www.walmart.com/ip/53596259
# ['$', '17', '.', '84']
# 80
# Processing: https://www.walmart.com/ip/53354247
# ['$', '9', '.', '99']
# 81
# Processing: https://www.walmart.com/ip/25243469
# ['$', '3', '.', '99']
# 82
# Processing: https://www.walmart.com/ip/19224591
# ['$', '12', '.', '42']
# 83
# Processing: https://www.walmart.com/ip/24057008
# ['$', '13', '.', '33']
# 84
# Processing: https://www.walmart.com/ip/55960420
# ['$', '5', '.', '75']
# 85
# Processing: https://www.walmart.com/ip/5794324
# ['$', '15', '.', '63']
# 86
# Processing: https://www.walmart.com/ip/15265445
# ['$', '13', '.', '10']
# 87
# Processing: https://www.walmart.com/ip/24595577
# ['$', '8', '.', '84']
# 88
# Processing: https://www.walmart.com/ip/20561488
# Retrying with exception
# ['$', '3', '.', '49']
# 89
# Processing: https://www.walmart.com/ip/56088903
# ['$', '23', '.', '83']
# 90
# Processing: https://www.walmart.com/ip/232709
# ['$', '8', '.', '97']
# 91
# Processing: https://www.walmart.com/ip/50091193
# ['$', '6', '.', '48']
# 92
# Processing: https://www.walmart.com/ip/5582973
# ['$', '5', '.', '68']
# 93
# Processing: https://www.walmart.com/ip/54360903
# ['$', '22', '.', '99']
# 94
# Processing: https://www.walmart.com/ip/1927334
# ['$', '8', '.', '60']
# 95
# Processing: https://www.walmart.com/ip/13315051
# ['$', '6', '.', '29']
# 96
# Processing: https://www.walmart.com/ip/17614642
# ['$', '13', '.', '26']
# 97
# Processing: https://www.walmart.com/ip/45144418
# ['$', '13', '.', '87']
# 98
# Processing: https://www.walmart.com/ip/14672516
# ['$', '8', '.', '34']
# 99
# Processing: https://www.walmart.com/ip/2322884
# ['$', '12', '.', '28']
# 100
# Processing: https://www.walmart.com/ip/20931169
# ['$', '14', '.', '03']
# 101
# Processing: https://www.walmart.com/ip/10887231
# Retrying with exception
# ['$', '7', '.', '19']
# 102
# Processing: https://www.walmart.com/ip/10181141
# ['$', '7', '.', '74']
# 103
# Processing: https://www.walmart.com/ip/405744
# ['$', '5', '.', '28']
# 104
# Processing: https://www.walmart.com/ip/15906968
# ['$', '11', '.', '33']
# 105
# Processing: https://www.walmart.com/ip/55344308
# ['$', '15', '.', '34']
# 106
# Processing: https://www.walmart.com/ip/56174414
# ['$', '9', '.', '53']
# 107
# Processing: https://www.walmart.com/ip/3868274
# ['$', '8', '.', '18']
# 108
# Processing: https://www.walmart.com/ip/43379021
# ['$', '13', '.', '56']
# 109
# Processing: https://www.walmart.com/ip/53399380
# ['$', '9', '.', '95']
# 110
# Processing: https://www.walmart.com/ip/2540216
# ['$', '16', '.', '22']
# 111
# Processing: https://www.walmart.com/ip/55600076
# ['$', '6', '.', '48']
# 112
# Processing: https://www.walmart.com/ip/47323942
# ['$', '31', '.', '99']
# 113
# Processing: https://www.walmart.com/ip/52099905
# ['$', '20', '.', '64']
# 114
# Processing: https://www.walmart.com/ip/738055887
# ['$', '15', '.', '23']
# 115
# Processing: https://www.walmart.com/ip/10970462
# ['$', '9', '.', '40']
# 116
# Processing: https://www.walmart.com/ip/10753000
# ['$', '7', '.', '98']
# 117
# Processing: https://www.walmart.com/ip/9603732
# ['$', '7', '.', '58']
# 118
# Processing: https://www.walmart.com/ip/45760954
# ['$', '22', '.', '21']
# 119
# Processing: https://www.walmart.com/ip/56022454
# ['$', '6', '.', '08']
# 120
# Processing: https://www.walmart.com/ip/37501803
# ['$', '3', '.', '99']
# 121
# Processing: https://www.walmart.com/ip/45969081
# ['$', '13', '.', '56']
# 122
# Processing: https://www.walmart.com/ip/10764637
# Retrying with exception
# ['$', '17', '.', '99']
# 123
# Processing: https://www.walmart.com/ip/55858656
# ['$', '9', '.', '79']
# 124
# Processing: https://www.walmart.com/ip/650983757
# ['$', '20', '.', '26']
# 125
# Processing: https://www.walmart.com/ip/49742601
# ['$', '5', '.', '57']
# 126
# Processing: https://www.walmart.com/ip/15977768
# ['$', '13', '.', '32']
# 127
# Processing: https://www.walmart.com/ip/22043801
# ['$', '13', '.', '81']
# 128
# Processing: https://www.walmart.com/ip/50554632
# ['$', '13', '.', '87']
# 129
# Processing: https://www.walmart.com/ip/338580883
# ['$', '9', '.', '99']
# 130
# Processing: https://www.walmart.com/ip/52867497
# ['$', '9', '.', '40']
# 131
# Processing: https://www.walmart.com/ip/49524370
# ['$', '9', '.', '99']
# 132
# Processing: https://www.walmart.com/ip/55971815
# ['$', '15', '.', '94']
# 133
# Processing: https://www.walmart.com/ip/10971892
# ['$', '7', '.', '99']
# 134
# Processing: https://www.walmart.com/ip/49742970
# ['$', '8', '.', '12']
# 135
# Processing: https://www.walmart.com/ip/1955935
# ['$', '20', '.', '99']
# 136
# Processing: https://www.walmart.com/ip/405370
# ['$', '5', '.', '99']
# 137
# Processing: https://www.walmart.com/ip/8199936
# ['$', '7', '.', '19']
# 138
# Processing: https://www.walmart.com/ip/45761465
# ['$', '56', '.', '40']
# 139
# Processing: https://www.walmart.com/ip/54360106
# ['$', '10', '.', '77']
# 140
# Processing: https://www.walmart.com/ip/15227310
# ['$', '8', '.', '23']
# 141
# Processing: https://www.walmart.com/ip/802252084
# ['$', '14', '.', '19']
# 142
# Processing: https://www.walmart.com/ip/56144374
# ['$', '22', '.', '90']
# 143
# Processing: https://www.walmart.com/ip/25666120
# ['$', '12', '.', '57']
# 144
# Processing: https://www.walmart.com/ip/455118
# ['$', '13', '.', '45']
# 145
# Processing: https://www.walmart.com/ip/8131253
# ['$', '7', '.', '19']
# 146
# Processing: https://www.walmart.com/ip/470347
# ['$', '7', '.', '19']
# 147
# Processing: https://www.walmart.com/ip/3389393
# ['$', '12', '.', '06']
# 148
# Processing: https://www.walmart.com/ip/14289657
# ['$', '8', '.', '49']
# 149
# Processing: https://www.walmart.com/ip/3362627
# ['$', '10', '.', '48']
# 150
# Processing: https://www.walmart.com/ip/56100596
# ['$', '13', '.', '25']
# 151
# Processing: https://www.walmart.com/ip/15528404
# ['$', '4', '.', '78']
# 152
# Processing: https://www.walmart.com/ip/5770768
# ['$', '9', '.', '28']
# 153
# Processing: https://www.walmart.com/ip/21122376
# ['$', '7', '.', '99']
# 154
# Processing: https://www.walmart.com/ip/52100236
# ['$', '6', '.', '39']
# 155
# Processing: https://www.walmart.com/ip/53276482
# ['$', '9', '.', '99']
# 156
# Processing: https://www.walmart.com/ip/4662531
# ['$', '8', '.', '01']
# 157
# Processing: https://www.walmart.com/ip/446164
# ['$', '9', '.', '52']
# 158
# Processing: https://www.walmart.com/ip/21050382
# ['$', '8', '.', '99']
# 159
# Processing: https://www.walmart.com/ip/473951
# ['$', '5', '.', '98']
# 160
# Processing: https://www.walmart.com/ip/50250499
# ['$', '8', '.', '99']
# 161
# Processing: https://www.walmart.com/ip/11976839
# ['$', '6', '.', '80']
# 162
# Processing: https://www.walmart.com/ip/376640
# ['$', '9', '.', '98']
# 163
# Processing: https://www.walmart.com/ip/29269258
# ['$', '9', '.', '85']
# 164
# Processing: https://www.walmart.com/ip/50554266
# ['$', '7', '.', '48']
# 165
# Processing: https://www.walmart.com/ip/55832644
# ['$', '16', '.', '14']
# 166
# Processing: https://www.walmart.com/ip/46681033
# ['$', '11', '.', '92']
# 167
# Processing: https://www.walmart.com/ip/54785434
# ['$', '7', '.', '19']
# 168
# Processing: https://www.walmart.com/ip/55678067
# ['$', '13', '.', '23']
# 169
# Processing: https://www.walmart.com/ip/8153774
# ['$', '7', '.', '97']
# 170
# Processing: https://www.walmart.com/ip/55963109
# ['$', '15', '.', '39']
# 171
# Processing: https://www.walmart.com/ip/2031251
# ['$', '10', '.', '09']
# 172
# Processing: https://www.walmart.com/ip/713730
# ['$', '7', '.', '51']
# 173
# Processing: https://www.walmart.com/ip/1245634
# ['$', '22', '.', '22']
# 174
# Processing: https://www.walmart.com/ip/22898614
# ['$', '10', '.', '27']
# 175
# Processing: https://www.walmart.com/ip/55600719
# ['$', '6', '.', '53']
# 176
# Processing: https://www.walmart.com/ip/8590508
# ['$', '7', '.', '98']
# 177
# Processing: https://www.walmart.com/ip/27819497
# ['$', '15', '.', '96']
# 178
# Processing: https://www.walmart.com/ip/48449388
# ['$', '7', '.', '99']
# 179
# Processing: https://www.walmart.com/ip/20636023
# ['$', '8', '.', '70']
# 180
# Processing: https://www.walmart.com/ip/2195030
# ['$', '32', '.', '25']
# 181
# Processing: https://www.walmart.com/ip/55366699
# ['$', '6', '.', '98']
# 182
# Processing: https://www.walmart.com/ip/51797762
# ['$', '13', '.', '70']
# 183
# Processing: https://www.walmart.com/ip/40793581
# ['$', '9', '.', '84']
# 184
# Processing: https://www.walmart.com/ip/55698168
# ['$', '13', '.', '89']
# 185
# Processing: https://www.walmart.com/ip/15441719
# ['$', '7', '.', '97']
# 186
# Processing: https://www.walmart.com/ip/23732941
# ['$', '33', '.', '52']
# 187
# Processing: https://www.walmart.com/ip/441896
# ['$', '7', '.', '99']
# 188
# Processing: https://www.walmart.com/ip/50987056
# ['$', '6', '.', '86']
# 189
# Processing: https://www.walmart.com/ip/8199792
# Retrying with exception
# ['$', '11', '.', '13']
# 190
# Processing: https://www.walmart.com/ip/53691956
# ['$', '7', '.', '25']
# 191
# Processing: https://www.walmart.com/ip/2617863
# ['$', '8', '.', '02']
# 192
# Processing: https://www.walmart.com/ip/50554692
# ['$', '12', '.', '78']
# 193
# Processing: https://www.walmart.com/ip/665268
# ['$', '12', '.', '89']
# 194
# Processing: https://www.walmart.com/ip/604395994
# ['$', '16', '.', '18']
# 195
# Processing: https://www.walmart.com/ip/49525221
# ['$', '8', '.', '26']
# 196
# Processing: https://www.walmart.com/ip/641268111
# ['$', '13', '.', '25']
# 197
# Processing: https://www.walmart.com/ip/55971478
# ['$', '17', '.', '34']
# 198
# Processing: https://www.walmart.com/ip/39563545
# ['$', '9', '.', '58']
# 199
# Processing: https://www.walmart.com/ip/55679631
# ['$', '8', '.', '99']
# 200
# Processing: https://www.walmart.com/ip/16344696
# ['$', '9', '.', '88']
# 201
# Processing: https://www.walmart.com/ip/15975052
# ['$', '6', '.', '86']
# 202
# Processing: https://www.walmart.com/ip/45844070
# ['$', '8', '.', '23']
# 203
# Processing: https://www.walmart.com/ip/55217282
# ['$', '7', '.', '08']
# 204
# Processing: https://www.walmart.com/ip/14095873
# ['$', '7', '.', '48']
# 205
# Processing: https://www.walmart.com/ip/49983212
# ['$', '6', '.', '29']
# 206
# Processing: https://www.walmart.com/ip/45143765
# ['$', '5', '.', '83']
# 207
# Processing: https://www.walmart.com/ip/461539
# ['$', '28', '.', '11']
# 208
# Processing: https://www.walmart.com/ip/49622373
# ['$', '8', '.', '99']
# 209
# Processing: https://www.walmart.com/ip/56176315
# ['$', '14', '.', '53']
# 210
# Processing: https://www.walmart.com/ip/10970822
# ['$', '9', '.', '92']
# 211
# Processing: https://www.walmart.com/ip/55678092
# ['$', '5', '.', '26']
# 212
# Processing: https://www.walmart.com/ip/40794850
# ['$', '42', '.', '48']
# 213
# Processing: https://www.walmart.com/ip/55699278
# ['$', '16', '.', '38']
# 214
# Processing: https://www.walmart.com/ip/55219881
# ['$', '4', '.', '49']
# 215
# Processing: https://www.walmart.com/ip/405815
# ['$', '5', '.', '95']
# 216
# Processing: https://www.walmart.com/ip/20438693
# ['$', '16', '.', '00']
# 217
# Processing: https://www.walmart.com/ip/3637110
# ['$', '7', '.', '19']
# 218
# Processing: https://www.walmart.com/ip/56143020
# ['$', '8', '.', '76']
# 219
# Processing: https://www.walmart.com/ip/56106258
# ['$', '19', '.', '52']
# 220
# Processing: https://www.walmart.com/ip/55699155
# ['$', '8', '.', '79']
# 221
# Processing: https://www.walmart.com/ip/463336
# ['$', '7', '.', '99']
# 222
# Processing: https://www.walmart.com/ip/51333481
# ['$', '12', '.', '63']
# 223
# Processing: https://www.walmart.com/ip/10158649
# ['$', '7', '.', '97']
# 224
# Processing: https://www.walmart.com/ip/55344338
# ['$', '15', '.', '31']
# 225
# Processing: https://www.walmart.com/ip/6094161
# ['$', '7', '.', '99']
# 226
# Processing: https://www.walmart.com/ip/10998325
# ['$', '9', '.', '99']
# 227
# Processing: https://www.walmart.com/ip/3956749
# ['$', '27', '.', '52']
# 228
# Processing: https://www.walmart.com/ip/4054264
# ['$', '7', '.', '85']
# 229
# Processing: https://www.walmart.com/ip/55747640
# Retrying with exception
# ['$', '8', '.', '78']
# 230
# Processing: https://www.walmart.com/ip/40794833
# ['$', '8', '.', '49']
# 231
# Processing: https://www.walmart.com/ip/56076648
# ['$', '16', '.', '66']
# 232
# Processing: https://www.walmart.com/ip/32166695
# ['$', '7', '.', '19']
# 233
# Processing: https://www.walmart.com/ip/55520911
# ['$', '18', '.', '75']
# 234
# Processing: https://www.walmart.com/ip/5572973
# ['$', '7', '.', '99']
# 235
# Processing: https://www.walmart.com/ip/4456443
# ['$', '8', '.', '35']
# 236
# Processing: https://www.walmart.com/ip/19404084
# ['$', '14', '.', '53']
# 237
# Processing: https://www.walmart.com/ip/55699203
# ['$', '20', '.', '37']
# 238
# Processing: https://www.walmart.com/ip/53840186
# ['$', '10', '.', '50']
# 239
# Processing: https://www.walmart.com/ip/5583235
# ['$', '11', '.', '48']
# 240
# Processing: https://www.walmart.com/ip/53631751
# ['$', '13', '.', '99']
# 241
# Processing: https://www.walmart.com/ip/4244217
# ['$', '7', '.', '99']
# 242
# Processing: https://www.walmart.com/ip/33816398
# ['$', '3', '.', '99']
# 243
# Processing: https://www.walmart.com/ip/11019822
# ['$', '7', '.', '99']
# 244
# Processing: https://www.walmart.com/ip/470266
# ['$', '15', '.', '10']
# 245
# Processing: https://www.walmart.com/ip/2217240
# ['$', '19', '.', '59']
# 246
# Processing: https://www.walmart.com/ip/6021313
# ['$', '8', '.', '30']
# 247
# Processing: https://www.walmart.com/ip/2402092
# ['$', '6', '.', '36']
# 248
# Processing: https://www.walmart.com/ip/405053
# ['$', '7', '.', '19']
# 249
# Processing: https://www.walmart.com/ip/49118408
# ['$', '18', '.', '02']
# 250
# Processing: https://www.walmart.com/ip/16415395
# ['$', '4', '.', '95']
# 251
# Processing: https://www.walmart.com/ip/23367125
# ['$', '14', '.', '20']
# 252
# Processing: https://www.walmart.com/ip/1276507
# ['$', '13', '.', '78']
# 253
# Processing: https://www.walmart.com/ip/54976381
# ['$', '35', '.', '05']
# 254
# Processing: https://www.walmart.com/ip/444087
# ['$', '7', '.', '08']
# 255
# Processing: https://www.walmart.com/ip/52609894
# ['$', '16', '.', '98']
# 256
# Processing: https://www.walmart.com/ip/20898979
# ['$', '7', '.', '71']
# 257
# Processing: https://www.walmart.com/ip/55601097
# ['$', '5', '.', '38']
# 258
# Processing: https://www.walmart.com/ip/2072002
# ['$', '9', '.', '24']
# 259
# Processing: https://www.walmart.com/ip/12454868
# ['$', '23', '.', '90']
# 260
# Processing: https://www.walmart.com/ip/22220608
# ['$', '12', '.', '42']
# 261
# Processing: https://www.walmart.com/ip/270716357
# ['$', '13', '.', '89']
# 262
# Processing: https://www.walmart.com/ip/55863324
# ['$', '10', '.', '07']
# 263
# Processing: https://www.walmart.com/ip/55818919
# ['$', '6', '.', '52']
# 264
# Processing: https://www.walmart.com/ip/45057108
# ['$', '11', '.', '53']
# 265
# Processing: https://www.walmart.com/ip/55391504
# ['$', '9', '.', '40']
# 266
# Processing: https://www.walmart.com/ip/55424760
# ['$', '8', '.', '99']
# 267
# Processing: https://www.walmart.com/ip/55601566
# ['$', '5', '.', '67']
# 268
# Processing: https://www.walmart.com/ip/10230643
# ['$', '7', '.', '97']
# 269
# Processing: https://www.walmart.com/ip/2127954
# ['$', '7', '.', '50']
# 270
# Processing: https://www.walmart.com/ip/5496732
# ['$', '6', '.', '99']
# 271
# Processing: https://www.walmart.com/ip/14829268
# ['$', '5', '.', '65']
# 272
# Processing: https://www.walmart.com/ip/299301311
# ['$', '12', '.', '59']
# 273
# Processing: https://www.walmart.com/ip/392599
# ['$', '14', '.', '20']
# 274
# Processing: https://www.walmart.com/ip/438978
# ['$', '6', '.', '17']
# 275
# Processing: https://www.walmart.com/ip/55962701
# ['$', '15', '.', '95']
# 276
# Processing: https://www.walmart.com/ip/53087569
# ['$', '10', '.', '97']
# 277
# Processing: https://www.walmart.com/ip/13847299
# ['$', '7', '.', '19']
# 278
# Processing: https://www.walmart.com/ip/33940870
# ['$', '7', '.', '99']
# 279
# Processing: https://www.walmart.com/ip/14046342
# ['$', '7', '.', '99']
# Retrying with exception
# ['$', '7', '.', '99']
# 280
# Processing: https://www.walmart.com/ip/17476810
# ['$', '8', '.', '79']
# 281
# Processing: https://www.walmart.com/ip/135002987
# ['$', '24', '.', '57']
# 282
# Processing: https://www.walmart.com/ip/17476648
# ['$', '8', '.', '99']
# 283
# Processing: https://www.walmart.com/ip/55746862
# ['$', '16', '.', '52']
# 284
# Processing: https://www.walmart.com/ip/25116816
# ['$', '8', '.', '52']
# 285
# Processing: https://www.walmart.com/ip/21919014
# ['$', '2', '.', '99']
# 286
# Processing: https://www.walmart.com/ip/25111287
# ['$', '8', '.', '76']
# 287
# Processing: https://www.walmart.com/ip/33816942
# ['$', '7', '.', '19']
# 288
# Processing: https://www.walmart.com/ip/2003348
# ['$', '11', '.', '54']
# 289
# Processing: https://www.walmart.com/ip/17615443
# ['$', '13', '.', '10']
# 290
# Processing: https://www.walmart.com/ip/10763542
# ['$', '8', '.', '99']
# 291
# Processing: https://www.walmart.com/ip/21974732
# ['$', '18', '.', '19']
# 292
# Processing: https://www.walmart.com/ip/517512
# ['$', '8', '.', '10']
# 293
# Processing: https://www.walmart.com/ip/38188374
# ['$', '7', '.', '97']
# 294
# Processing: https://www.walmart.com/ip/15546883
# ['$', '14', '.', '52']
# 295
# Processing: https://www.walmart.com/ip/55971321
# ['$', '20', '.', '35']
# 296
# Processing: https://www.walmart.com/ip/299922740
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# Retrying with exception
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-6a23d6441a6c> in WalmartParser(url)
#      11             doc = html.fromstring(page)
# ---> 12             script_data = doc.xpath('//script[contains(., "Specifications")]/text()')[0]
#      13
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-12-5561504f8a3d> in <module>()
#       1 if __name__ == "__main__":
# ----> 2     ReadAsin(formatted_asin[1500:1800])
#
# <ipython-input-10-3ff088c9870b> in ReadAsin(AsinList)
#       6         url = "https://www.walmart.com/ip/"+i
#       7         print("Processing: "+url)
# ----> 8         extracted_data.append(WalmartParser(url))
#       9         count += 1
#      10         #sleep(5)
#
# <ipython-input-9-6a23d6441a6c> in WalmartParser(url)
#     129         except Exception as e:
#     130             print("Retrying with exception ")
# --> 131             driver.get(url)
#     132             #print(driver)
#     133             rpage = requests.get(url,headers=headers)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     322         Loads a web page in the current browser session.
#     323         """
# --> 324         self.execute(Command.GET, {'url': url})
#     325
#     326     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
# --> 312             self.error_handler.check_response(response)
#     313             response['value'] = self._unwrap_value(
#     314                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=65.0.3325.162)
#   (Driver info: chromedriver=2.36.540470 (e522d04694c7ebea4ba8821272dbef4f9b818c91),platform=Windows NT 10.0.16299 x86_64)

# %%
print(len(extracted_data))
# Out:
# 296

# %%
f=open('data_walmart.json','w')
json.dump(extracted_data,f,indent=4)
