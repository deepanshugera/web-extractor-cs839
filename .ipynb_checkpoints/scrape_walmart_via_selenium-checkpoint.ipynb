# %%
from lxml import html  
import csv,os,json
import requests
from time import sleep
import ast
import re
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path=r'C:\Geckodriver\chromedriver.exe')
driver.set_page_load_timeout(500)

# %%
def WalmartParser(url):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.90 Safari/537.36'}
    driver.get(url)
    #print(driver)
    page = driver.page_source
    rpage = requests.get(url,headers=headers)
   
    while True:
        sleep(3)
        try:
            doc = html.fromstring(page)
            script_data = doc.xpath('//script[contains(., "Specifications")]/text()')[0]
            
            XPATH_NAME = '//h1[contains(@class,"prod-ProductTitle")]/div/text()'
            XPATH_SALE_PRICE = '//span[@class="display-inline-block-xs prod-PaddingRight--s"]//text()'
            XPATH_CATEGORY = '//ol[@class="breadcrumb-list "]//text()'
            XPATH_RATING = '//span[@class="seo-avg-rating" and @itemprop="ratingValue"]/text()'
             
            
            ''' 
            XPATH_SALE_PRICE = '//span[contains(@class,"offer-price") and contains(@class,"a-size-medium")]//text()'
            #XPATH_ORIGINAL_PRICE = '//td[contains(text(),"List Price") or contains(text(),"M.R.P") or contains(text(),"Price")]/following-sibling::td/text()'
            XPATH_CATEGORY = '//a[@class="a-link-normal a-color-tertiary"]//text()'
            XPATH_AVAILABILITY = '//div[@id="availability"]//text()' 
            XPATH_AUTHOR = '//a[contains(@class,"contributorNameID")]//text()'
            XPATH_ISBN10 = '//li/b[contains(text(),"ISBN-10:")]/following-sibling::text()'
            XPATH_PAGES = '//li/b[contains(text(),"Paperback")]/following-sibling::text()'
            XPATH_PUBLISHER = '//li/b[contains(text(),"Publisher")]/following-sibling::text()'
            XPATH_LANGUAGE = '//li/b[contains(text(),"Language")]/following-sibling::text()'
            XPATH_DIMENSIONS = '//li/b[contains(text(),"Dimensions")]/following-sibling::text()'
            XPATH_WEIGHT = '//li/b[contains(text(),"Weight")]/following-sibling::text()'
            XPATH_RATING = '//li/b[contains(text(),"Average Customer Review:")]/following-sibling::span/span/a/i/span/text()'
            '''
           
            RAW_NAME = doc.xpath(XPATH_NAME)
            RAW_SALE_PRICE = doc.xpath(XPATH_SALE_PRICE)
            RAW_CATEGORY = doc.xpath(XPATH_CATEGORY)
            RAW_RATING = doc.xpath(XPATH_RATING)
            print(RAW_SALE_PRICE)
           # RAW_AUTHOR = doc.xpath(XPATH_AUTHOR)
            '''
            
            
            ##RAW_ORIGINAL_PRICE = doc.xpath(XPATH_ORIGINAL_PRICE)
            RAw_AVAILABILITY = doc.xpath(XPATH_AVAILABILITY)
            
            RAW_ISBN10 = doc.xpath(XPATH_ISBN10)
            RAW_PAGES = doc.xpath(XPATH_PAGES)
            RAW_PUBLISHER = doc.xpath(XPATH_PUBLISHER) 
            RAW_LANGUAGE = doc.xpath(XPATH_LANGUAGE)
            RAW_DIMENSIONS = doc.xpath(XPATH_DIMENSIONS)
            RAW_WEIGHT = doc.xpath(XPATH_WEIGHT)
            RAW_RATING = doc.xpath(XPATH_RATING)
            '''
            
            AUTHOR, PUBLISHER, LANGUAGE, PAGES, ISBN10, DIMENSIONS = None, None, None, None, None, None
            

            data = re.search(r'"Specifications":(.*?),"ShortDescription', script_data).group(1)
            #print(data)
            #import json
            #data = json.loads(data)
            data = ast.literal_eval(data)
            data = (data["specifications"]["values"][0])
            for item in data:
                #print item
                for k,v in item.items():
                    if k == "author":
                        RAW_AUTHOR = v['values']
                        AUTHOR = ''.join(RAW_AUTHOR).strip() if RAW_AUTHOR else None
                        
                    elif k == "publisher":
                        RAW_PUBLISHER = v['values']
                        PUBLISHER = ''.join(RAW_PUBLISHER).strip() if RAW_PUBLISHER else None

                    elif k == "languages":
                        RAW_LANGUAGE = v['values']
                        LANGUAGE = ''.join(RAW_LANGUAGE).strip() if RAW_LANGUAGE else None
                        
                    elif k == "number_of_pages":
                        RAW_PAGES = v['values']
                        PAGES = ''.join(RAW_PAGES).strip() if RAW_PAGES else None

                    elif k == "isbn-10":
                        RAW_ISBN10 = v['values']
                        ISBN10 = ''.join(RAW_ISBN10).strip() if RAW_ISBN10 else None
                    elif k == "dimension":
                        RAW_DIMENSIONS = v['values']
                        DIMENSIONS = ''.join(RAW_DIMENSIONS).strip() if RAW_DIMENSIONS else None
                    
            #AUTHOR = data
            
            #print AUTHOR
 
            NAME = ' '.join(''.join(RAW_NAME).split()) if RAW_NAME else None
            SALE_PRICE = ' '.join(''.join(RAW_SALE_PRICE).split()).strip() if RAW_SALE_PRICE else None
            CATEGORY = ' > '.join([i.strip() for i in RAW_CATEGORY]) if RAW_CATEGORY else None
            RATING = ''.join(RAW_RATING).strip() if RAW_RATING else None
            
           
            
            #print AUTHOR, PAGES, PUBLISHER
            '''
            WEIGHT = ''.join(RAW_WEIGHT).strip().strip('()').strip() if RAW_WEIGHT else None
            RATING = ''.join(RAW_RATING).strip() if RAW_RATING else None
            #if not ORIGINAL_PRICE:
                #ORIGINAL_PRICE = SALE_PRICE
                '''
 
            if rpage.status_code!=200 or not NAME or NAME == "":
                raise ValueError('captha')
            data = {
                    'NAME':NAME,
                    'SALE_PRICE':SALE_PRICE,
                    'CATEGORY':CATEGORY,
                   # 'AVAILABILITY':AVAILABILITY,
                    'URL':url,
                    'AUTHOR' : AUTHOR,
                    'ISBN10' : ISBN10,
                    'PAGES' : PAGES,
                    'PUBLISHER' : PUBLISHER,
                    'LANGUAGE' : LANGUAGE,
                    'DIMENSIONS' : DIMENSIONS,
                    #'WEIGHT' : WEIGHT,
                    'RATING' : RATING,
                    }
 
            return data
        except Exception as e:
            print("Retrying with exception ")
            driver.get(url)
            #print(driver)
            rpage = requests.get(url,headers=headers)
            page = driver.page_source

# %%
extracted_data = []
def ReadAsin(AsinList):
    count = 0
    # AsinList = csv.DictReader(open(os.path.join(os.path.dirname(__file__),"Asinfeed.csv")))
    for i in AsinList:
        url = "https://www.walmart.com/ip/"+i
        print("Processing: "+url)
        extracted_data.append(WalmartParser(url))
        count += 1
        #sleep(5)
        print(count)
    f=open('data_walmart.json','w')
    json.dump(extracted_data,f,indent=4)

# %%
formatted_asin = []
df = pd.read_csv("walmart_product_asins.csv")
for index, row in df.iterrows():
    #print(row[1])
    formatted_asin.append(str(row[1]))

# %%
if __name__ == "__main__":
    ReadAsin(formatted_asin[1224:1500])
# Out:
# Processing: https://www.walmart.com/ip/15694630
# ['$', '9', '.', '99']
# 1
# Processing: https://www.walmart.com/ip/2012881
# ['$', '13', '.', '89']
# 2
# Processing: https://www.walmart.com/ip/21053044
# ['$', '21', '.', '06']
# 3
# Processing: https://www.walmart.com/ip/46592215
# ['$', '19', '.', '97']
# 4
# Processing: https://www.walmart.com/ip/26887946
# ['$', '6', '.', '71']
# 5
# Processing: https://www.walmart.com/ip/405289
# ['$', '7', '.', '19']
# 6
# Processing: https://www.walmart.com/ip/55311910
# ['$', '22', '.', '00']
# 7
# Processing: https://www.walmart.com/ip/42486588
# ['$', '7', '.', '97']
# 8
# Processing: https://www.walmart.com/ip/24829150
# ['$', '16', '.', '45']
# 9
# Processing: https://www.walmart.com/ip/37279439
# ['$', '28', '.', '91']
# 10
# Processing: https://www.walmart.com/ip/751631
# ['$', '8', '.', '99']
# 11
# Processing: https://www.walmart.com/ip/44453710
# ['$', '9', '.', '96']
# 12
# Processing: https://www.walmart.com/ip/50440661
# ['$', '38', '.', '83']
# 13
# Processing: https://www.walmart.com/ip/55600355
# ['$', '8', '.', '98']
# 14
# Processing: https://www.walmart.com/ip/25951650
# ['$', '2', '.', '21']
# 15
# Processing: https://www.walmart.com/ip/3543559
# ['$', '12', '.', '80']
# 16
# Processing: https://www.walmart.com/ip/4543533
# ['$', '13', '.', '25']
# 17
# Processing: https://www.walmart.com/ip/47049007
# ['$', '13', '.', '84']
# 18
# Processing: https://www.walmart.com/ip/45762526
# ['$', '19', '.', '04']
# 19
# Processing: https://www.walmart.com/ip/56144743
# ['$', '14', '.', '84']
# 20
# Processing: https://www.walmart.com/ip/10178431
# ['$', '8', '.', '99']
# 21
# Processing: https://www.walmart.com/ip/353523925
# ['$', '8', '.', '20']
# 22
# Processing: https://www.walmart.com/ip/12340934
# ['$', '7', '.', '97']
# 23
# Processing: https://www.walmart.com/ip/470520
# ['$', '7', '.', '99']
# 24
# Processing: https://www.walmart.com/ip/55601580
# ['$', '12', '.', '96']
# 25
# Processing: https://www.walmart.com/ip/55863313
# ['$', '16', '.', '98']
# 26
# Processing: https://www.walmart.com/ip/56074511
# ['$', '22', '.', '17']
# 27
# Processing: https://www.walmart.com/ip/56144749
# ['$', '6', '.', '29']
# 28
# Processing: https://www.walmart.com/ip/29459197
# ['$', '6', '.', '69']
# 29
# Processing: https://www.walmart.com/ip/405055
# ['$', '7', '.', '99']
# 30
# Processing: https://www.walmart.com/ip/10752999
# ['$', '5', '.', '43']
# 31
# Processing: https://www.walmart.com/ip/546011620
# ['$', '34', '.', '40']
# 32
# Processing: https://www.walmart.com/ip/52705419
# ['$', '11', '.', '55']
# 33
# Processing: https://www.walmart.com/ip/55034094
# ['$', '38', '.', '73']
# 34
# Processing: https://www.walmart.com/ip/504180062
# ['$', '21', '.', '80']
# 35
# Processing: https://www.walmart.com/ip/22982144
# ['$', '9', '.', '78']
# 36
# Processing: https://www.walmart.com/ip/48928146
# ['$', '4', '.', '49']
# 37
# Processing: https://www.walmart.com/ip/38412213
# ['$', '8', '.', '99']
# 38
# Processing: https://www.walmart.com/ip/33431629
# ['$', '14', '.', '20']
# 39
# Processing: https://www.walmart.com/ip/444430
# ['$', '9', '.', '76']
# 40
# Processing: https://www.walmart.com/ip/19532376
# ['$', '9', '.', '39']
# 41
# Processing: https://www.walmart.com/ip/21103697
# ['$', '7', '.', '78']
# 42
# Processing: https://www.walmart.com/ip/46923079
# ['$', '10', '.', '59']
# 43
# Processing: https://www.walmart.com/ip/19701301
# ['$', '34', '.', '82']
# 44
# Processing: https://www.walmart.com/ip/56176550
# ['$', '2', '.', '53']
# 45
# Processing: https://www.walmart.com/ip/4631495
# ['$', '8', '.', '99']
# 46
# Processing: https://www.walmart.com/ip/11982197
# ['$', '18', '.', '09']
# 47
# Processing: https://www.walmart.com/ip/48449462
# ['$', '9', '.', '28']
# 48
# Processing: https://www.walmart.com/ip/16756140
# ['$', '2', '.', '99']
# 49
# Processing: https://www.walmart.com/ip/37784013
# ['$', '7', '.', '48']
# 50
# Processing: https://www.walmart.com/ip/50091897
# ['$', '6', '.', '29']
# 51
# Processing: https://www.walmart.com/ip/46592140
# ['$', '26', '.', '14']
# 52
# Processing: https://www.walmart.com/ip/802267
# ['$', '5', '.', '49']
# 53
# Processing: https://www.walmart.com/ip/360430832
# ['$', '7', '.', '99']
# 54
# Processing: https://www.walmart.com/ip/649809677
# ['$', '20', '.', '36']
# 55
# Processing: https://www.walmart.com/ip/35258811
# ['$', '5', '.', '99']
# 56
# Processing: https://www.walmart.com/ip/7898056
# ['$', '9', '.', '42']
# 57
# Processing: https://www.walmart.com/ip/2672452
# ['$', '61', '.', '03']
# 58
# Processing: https://www.walmart.com/ip/2062090
# ['$', '10', '.', '93']
# 59
# Processing: https://www.walmart.com/ip/55259733
# ['$', '8', '.', '18']
# 60
# Processing: https://www.walmart.com/ip/56140613
# ['$', '9', '.', '40']
# 61
# Processing: https://www.walmart.com/ip/55620549
# ['$', '10', '.', '87']
# 62
# Processing: https://www.walmart.com/ip/53640286
# ['$', '6', '.', '99']
# 63
# Processing: https://www.walmart.com/ip/5402025
# ['$', '8', '.', '27']
# 64
# Processing: https://www.walmart.com/ip/56119224
# ['$', '3', '.', '58']
# 65
# Processing: https://www.walmart.com/ip/26351434
# ['$', '9', '.', '42']
# 66
# Processing: https://www.walmart.com/ip/52611672
# ['$', '16', '.', '15']
# 67
# Processing: https://www.walmart.com/ip/555458343
# ['$', '18', '.', '22']
# 68
# Processing: https://www.walmart.com/ip/21851251
# ['$', '6', '.', '39']
# 69
# Processing: https://www.walmart.com/ip/8220766
# ['$', '14', '.', '29']
# 70
# Processing: https://www.walmart.com/ip/56141886
# ['$', '12', '.', '78']
# 71
# Processing: https://www.walmart.com/ip/29272096
# ['$', '13', '.', '27']
# 72
# Processing: https://www.walmart.com/ip/55342693
# ['$', '22', '.', '87']
# 73
# Processing: https://www.walmart.com/ip/44979451
# ['$', '5', '.', '49']
# 74
# Processing: https://www.walmart.com/ip/45762585
# ['$', '9', '.', '99']
# 75
# Processing: https://www.walmart.com/ip/43908078
# ['$', '11', '.', '17']
# 76
# Processing: https://www.walmart.com/ip/3919041
# ['$', '9', '.', '99']
# 77
# Processing: https://www.walmart.com/ip/55565064
# ['$', '11', '.', '70']
# 78
# Processing: https://www.walmart.com/ip/15528114
# ['$', '9', '.', '98']
# 79
# Processing: https://www.walmart.com/ip/2506433
# ['$', '5', '.', '39']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-bca05d022b46> in WalmartParser(url)
#     110             if rpage.status_code!=200 or not NAME or NAME == "":
# --> 111                 raise ValueError('captha')
#     112             data = {
#
# ValueError: captha
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2f14f0e5793e> in <module>()
#       1 if __name__ == "__main__":
# ----> 2     ReadAsin(formatted_asin[1145:1500])
#
# <ipython-input-28-3ff088c9870b> in ReadAsin(AsinList)
#       6         url = "https://www.walmart.com/ip/"+i
#       7         print("Processing: "+url)
# ----> 8         extracted_data.append(WalmartParser(url))
#       9         count += 1
#      10         #sleep(5)
#
# <ipython-input-27-bca05d022b46> in WalmartParser(url)
#     128             return data
#     129         except Exception as e:
# --> 130             print("Retrying with exception " + e)
#     131             driver.get(url)
#     132             #print(driver)
#
# TypeError: must be str, not ValueError

# %%
print(len(extracted_data))
# Out:
# 79
